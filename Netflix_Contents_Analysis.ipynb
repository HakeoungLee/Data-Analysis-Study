# %% [markdown]
# <a href="https://colab.research.google.com/github/HakeoungLee/Data-Analysis-Study/blob/default/Netflix_Contents_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글드라이브 연동
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

# 구글 드라이브 파일 확인
# !ls '/gdrive/My Drive/temp/'

# 반복되는 드라이브 경로 변수화
drive_path = '/gdrive/My Drive/temp/'
# Out:
# Mounted at /gdrive
#  매수종목1.txt					 ram_price.csv
#  매수종목2.txt					 ratings_small.txt
#  adult.data					 ratings_test.txt
#  auto-mpg.csv					 ratings_train.txt
#  bmi_500.csv					 sample1.pdf
#  citibike.csv					 sample2.pdf
#  매수종목.csv					 sample_merge.pdf
#  database					 sample.xlsx
#  data_mine.csv					 score.csv
#  data_population.csv				 seoul_train.csv
#  data_studentlist_en.csv			 stock-data.csv
#  day_care_center.csv				'stock price.xlsx'
#  demo.docx					'stock valuation.xlsx'
#  educational_attainment_supplementary_data.csv	 test.db.db
#  example.docx					 test.txt
#  height_weight.txt				 Traffic_Accident_2017.csv
#  HelloWorld.xlsx				 train.csv
#  little-char.png				 user_id_mean.csv
#  netflix.csv					 world_location.csv
#  park.csv					 주가데이터.xlsx
#  population_number.csv				 남북한발전전력량.xlsx

# %% [markdown]
# ## 라이브러리 호출

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from matplotlib import font_manager, rc
import matplotlib.font_manager as fm
import plotly.graph_objects as go
import plotly.express as px
import plotly as py
import folium
import datetime
import os
from plotly.offline import init_notebook_mode, iplot
py.offline.init_notebook_mode(connected = True)
import matplotlib.colors
from collections import Counter


from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AffinityPropagation
from sklearn.preprocessing import MultiLabelBinarizer 


import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# !apt -qq -y install fonts-nanum
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
# 색상
hex_colors=['#C1E1A7','#F9C1BD','#06ABC6','#622D24','#ABB5CD','#057129','#003366','#DDDDDD','#5B9BD5','#7030A0','#A2AE02','#00B050','#FFFF99','#FF3300','#FF66FF','#800000','#FF9900','#9900CC','#66FFFF','#FFFF00','#00FF00','#3366CC','#FFCCFF','#66FFCC','#B2B2B2','#0D8571','#FF5D5D','#B8ADF9','#F4DB9E','#D88C26','#0000CC','#D490FA']

# %% [markdown]
# #### 파일 불러오기

# %%
df = pd.read_csv(drive_path + 'netflix.csv')

# %% [markdown]
# ## 데이터 처리

# %% [markdown]
# #### 결측치 확인하기

# %%
for col in df.columns:
    x = "column: {:>10}\t Percent of NaN value: {:.2f}%".format(col, 100 * (df[col].isnull().sum() / df[col].shape[0]))
    print(x)
# Out:
# column:    show_id	 Percent of NaN value: 0.00%
# column:       type	 Percent of NaN value: 0.00%
# column:      title	 Percent of NaN value: 0.00%
# column:   director	 Percent of NaN value: 30.68%
# column:       cast	 Percent of NaN value: 9.22%
# column:    country	 Percent of NaN value: 6.51%
# column: date_added	 Percent of NaN value: 0.13%
# column: release_year	 Percent of NaN value: 0.00%
# column:     rating	 Percent of NaN value: 0.09%
# column:   duration	 Percent of NaN value: 0.00%
# column:  listed_in	 Percent of NaN value: 0.00%
# column: description	 Percent of NaN value: 0.00%

# %% [markdown]
# #### 그래프로 결측치 확인하기

# %%
msno.bar(df.iloc[:,:], figsize=(4,4), color=(0.8,0.5,0.2))

# %% [markdown]
# #### 결측치 데이터 제거

# %% [markdown]
# ###### 필요한 데이터 미리 추출하기

# %%
df10 = df.copy()
df10['date_added'] = pd.to_datetime(df10['date_added'])
df10.drop(['show_id', 'director', 'cast',  'description'], axis = 1, inplace = True)
df10['date_added'] = pd.to_datetime(df['date_added'])
df10.dropna(axis=0,inplace=True)
df10['year']= df10['date_added'].dt.year
df10['month']= df10['date_added'].dt.month
df10['day']= df10['date_added'].dt.day

# %%
df11 = df.copy()

cnt = [i for i in range(1, len(df11)+1)]

df11['show_id'] = cnt
df11.drop(['director','cast','description'],axis=1,inplace=True)
df11.dropna(axis=0, inplace=True)
df11['date_added'] = pd.to_datetime(df11['date_added'])

df11['year']= df11['date_added'].dt.year
df11['month']= df11['date_added'].dt.month
df11['day']= df11['date_added'].dt.day

df12 = df.copy()

# %%
msno.bar(df10.iloc[:,:], figsize=(4,4), color=(0.8,0.5,0.2))

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df.drop(['show_id','cast','director', 'description'], axis = 1, inplace = True)

# %% [markdown]
# *   날짜 변환시켜서 열에 추가

# %%
df['year']= df['date_added'].dt.year
df['month']= df['date_added'].dt.month
df['day']= df['date_added'].dt.day

# %% [markdown]
# - 결측치 데이터가 제거 되었는지 확인

# %%
msno.bar(df.iloc[:,:], figsize=(4,4), color=(0.8,0.5,0.2))

# %% [markdown]
# - 나머지 결측치 있는 데이터 전부 제거

# %%
df.dropna(axis=0,inplace=True)

# %%
msno.bar(df.iloc[:,:], figsize=(4,4), color=(0.8,0.5,0.2))

# %% [markdown]
# *  숫자 타입으로 변경

# %%
df['year'] = df['year'].astype('int')
df['month'] = df['month'].astype('int')
df['day'] = df['day'].astype('int')

# %% [markdown]
# #### 날짜 데이터를 요일 데이터로 변경시켜서 열 추가

# %%
def get_today_days(year,month,day):
    days = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'] # 요일별 리스트
    return days[datetime.date(year,month,day).weekday()]

day_week = [get_today_days(df['year'].iloc[i], df['month'].iloc[i], df['day'].iloc[i]) for i in range(len(df))]

df['day_week'] = day_week

# %% [markdown]
# #### 등급별 카테고리화

# %%
# 시청가능한 최저 나이로 rating str변환
rating_for_age = { 
    'TV-MA' : '18',  # 17세 미만의 어린이 혹은 청소년한테 부적절한 프로그램
    'TV-14' : '15',   # 14세 미만의 어린이 혹은 청소년이 시청하려면 보호자 지도가 권장되는 프로그램
    'TV-PG' : '12',   # 어린이가 시청하려면 보호자 지도가 권장되는 프로그램
    'R': '18',       # 일반적 성인 영화. 17세 미만의 경우 부모의 동반 필수
    'PG-13' : '14',   # 전체 관람가지만, 부모의 주의가 요구되며 13세 미만에게는 적절하지 않음
    'TV-Y' : '1',      # 영유아를 위한 프로그램
    'TV-Y7' : '7',   # 7세 이상 어린이를 위한 프로그램
    'PG' : '12',     # 전체 관람가지만, 폭력성이 존재하므로 어린이의 경우 보호자의 지도가 요구
    'TV-G' : '1',       # 모든 연령이 시청할 수 있는 프로그램. 다만 어린이를 대상으로 하지는 않았다
    'NR' : '19',           # NR은 Not Rated로 등급을 받지 않은 경우
    'G' : '1',         # 일반용
    'TV-Y7-FV' : '7',  # 7세 이상의 어린이를 위한 프로그램. 매우 경미한 가상의 폭력 묘사가 있음.
    'UR' : '19',     # 매겨진 등급을 거부
    'NC-17' : '19'   # 수위가 매우 높은 성인 영화. 18세 미만 관람불가
}
df['rating_age'] = df['rating'].replace(rating_for_age)

# 1 / 7 / 12 / 14,15 / 18,19
# 카테고리화
ages = df['rating_age'].astype(int)
bins = [0, 3, 11, 17, 19] 
labels = ['All', 'Children' ,'Teens', 'Adults']
rating_cat = pd.cut(ages, bins, labels = labels)
rating_cat
df['rating_age_cat'] = rating_cat

# %% [markdown]
# ####   duration을 분리시키기 위해 2가지 타입별 분류

# %%
movie = df[df['type'] == 'Movie']
movie = movie.copy()  # 데이터를 복사해 pandas 오류 방지
tvshow = df[df['type'] == 'TV Show']
tvshow = tvshow.copy()

tvshow_s = df11[df11['type'] == 'TV Show']
tvshow_s = tvshow_s.copy()
movie_s = df11[df11['type'] == 'Movie']
movie_s = movie_s.copy()

movie_list = movie.loc[:,'duration'].str.split(' ').str[0]
movie['duration'] = movie_list
movie['duration'] = movie['duration'].astype('int')

movie_s_list = movie_s.loc[:,'duration'].str.split(' ').str[0]
movie_s['duration'] = movie_s_list
movie_s['duration'] = movie_s['duration'].astype('int')

# %% [markdown]
# #### 영상시간에 따른 카테고리화 만들기
#  - 간단한 영화, 단편 영화, 영화, 장편영화, 매우 긴 영화

# %%
bins = [0, 50, 70, 130, 180, 250]
bins_label = ['simple_film', 'short_flim', 'film', 'long_film', 'long_long_film']
movie['time_category'] = pd.cut(x = movie['duration'],
                            bins=bins,
                            labels=bins_label)

bins_s = [0, 50, 70, 130, 180, 250]
bins_label_s = ['simple_film', 'short_flim', 'film', 'long_film', 'long_long_film']
movie_s['time_category'] = pd.cut(x = movie_s['duration'],
                            bins=bins_s,
                            labels=bins_label_s)

# %% [markdown]
# ## 그래프 분석

# %% [markdown]
# #### 어떤 나라가 넷플릭스 콘텐츠 생산을 가장 많이 했을까? (나라별 컨텐츠 수 비교)

# %%
#나라와 타입별로 데이터프레임 생성
count_type = df.groupby(['country']).count()
most_country = count_type['type'].to_frame().reset_index().sort_values(by='type', ascending=False)[:12]

#Seaborn이용하여 시각화
plt.figure(figsize=(15,5))
sns.set_context('paper', font_scale=1.2)
sns.barplot(x='country', y='type', data=most_country)
plt.ylabel('# of TV & Movie')
plt.xlabel('Country')
plt.show()
plt.close()

# %% [markdown]
# #### 유형별 컨텐츠 비교

# %% [markdown]
# ##### 전체 컨텐츠 타입(유형) 분석

# %%
# 14~21년도 컨텐츠 분석
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
labels = ['Movie',"Tv Show"]
type_counts = df10['type'].value_counts()
plt.pie(type_counts,labels=labels,explode=[0,0.1], autopct='%1.1f%%')
plt.title('2014-2021',fontsize = 20)

# 2. 2019년 type 분류 
df_type_2019 = df10[["type","year"]][df10['year']==2019].value_counts()
plt.subplot(2,2,3)
plt.pie(df_type_2019, labels=labels, explode=[0,0.1], autopct='%1.1f%%')
plt.title('2019',fontsize = 20)

# 3. 2020년 type 분류 
df_type_2020 = df10[["type","year"]][df10['year']==2020].value_counts()
plt.subplot(2,2,4)
plt.pie(df_type_2020, labels=labels, explode=[0,0.1], autopct='%1.1f%%')
plt.title('2020',fontsize = 20)

plt.show()

# %% [markdown]
# ##### 14년 ~ 21년 연도별 컨텐츠 타입 분석

# %%
import plotly.graph_objects as go

movie_per_year = [] 
tv_show_per_year = []

for i in range(2014,2021):
    m = df10.loc[(df10['type']=='Movie') & (df10['year']==i)]
    s = df10.loc[(df10['type']=='TV Show') & (df10['year']==i)]
    movie_per_year.append(len(m))
    tv_show_per_year.append(len(s))

trace1 = go.Scatter(x = [i for i in range(2014,2021)],y = movie_per_year, mode = 'lines+markers',name= 'Movie',)

trace2 = go.Scatter(x = [i for i in range(2014,2021)],y = tv_show_per_year, mode = 'lines+markers',name= 'TV Shows')

data=[trace1,trace2]

layout = go.Layout(title = "Contents per year", legend = dict(y= 1 , orientation="v"))

fig = go.Figure(data,layout=layout)
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a2842771-e78e-4342-98f4-a16a1fe16d57" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2842771-e78e-4342-98f4-a16a1fe16d57")) {
#                     Plotly.newPlot(
#                         'a2842771-e78e-4342-98f4-a16a1fe16d57',
#                         [{"mode": "lines+markers", "name": "Movie", "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "y": [19, 54, 247, 837, 1209, 1422, 1251]}, {"mode": "lines+markers", "name": "TV Shows", "type": "scatter", "x": [2014, 2015, 2016, 2017, 2018, 2019, 2020], "y": [6, 29, 174, 320, 353, 571, 639]}],
#                         {"legend": {"orientation": "v", "y": 1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scat ...

# %% [markdown]
# #### 연도별 전세계 넷플릭스 컨텐츠 생산 수

# %%
contents_per_year=df['release_year'].value_counts().reset_index()
contents_per_year.columns.values[0]='Year'
contents_per_year.columns.values[1]='Count'
plt.figure(figsize=[20,8])
contents_per_year2=contents_per_year[contents_per_year['Year']<2021].copy()
contents_per_year2.sort_values(by='Year',inplace=True)
sns.barplot(data=contents_per_year2,x='Year',y='Count')
plt.title('# of contents produced by year',fontsize=16)
plt.xlabel('Year')
plt.ylabel('Contents Per Year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 등급별 비율 확인
# - 2019년 2020년 연령비율 간의 상관관계 비교
# - 2020년에 코로나19 영향으로 인해 키즈, 패밀리 등급물이 더 많아짐.

# %% [markdown]
# ###### 넷플릭스 출범이후 연령별 데이터 비교

# %%
np_rating = rating_cat.value_counts()
labels = ['Red','Blue','Green','Yellow'] 
colors = sns.color_palette('hls',len(labels))

f, ax = plt.subplots(1, 2, figsize=(20, 8))
np_rating.plot.pie(explode=[0.05,0.05,0.05,0.05],autopct='%1.1f%%' ,ax=ax[0], fontsize=15, colors=colors)
ax[0].set_title('All Netfilx Rating',fontsize=25)
ax[0].set_ylabel('')

np_rating.plot.bar(ax=ax[1], rot=0, fontsize=15, color=colors)
ax[1].set_title('All Netfilx Rating',fontsize=25)

plt.show()

# %% [markdown]
# #### 요일별 넷플릭스 출시 분석
# - 넷플릭스는 주로 금요일에 출시를 하고 휴일에는 출시를 잘하지 않는다.
# - 주말에 사람들의 관심을 끌 수 있도록 금요일에 출시량이 2배가 넘음

# %%
labels = ['Red','Orange','Yello','Green','Blue','navy','violet'] ## 라벨
colors = sns.color_palette('hls',len(labels)) ## 라벨의 개수 만큼 색상 리스트 생성 

f, ax = plt.subplots(1, 2, figsize=(18, 8))
df['day_week'].value_counts().plot.pie(explode=[0.05,0.05,0.05,0.05,0.05,0.05,0.05],autopct='%1.1f%%' ,ax=ax[0], fontsize=20, colors=colors)
ax[0].set_title('Pie',fontsize=30)
ax[0].set_ylabel('')

df['day_week'].value_counts().plot.bar(ax=ax[1], rot=0, fontsize=20, color=colors)
ax[1].set_title('Bar',fontsize=30)
plt.show()

# %% [markdown]
# - 월별과 요일을 크로스 시켜 언제 출시를 많이하는지 확인하기

# %%
pd.crosstab(movie['month'],movie['day_week'],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col7{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col1{
#             background-color:  #e0f066;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col6{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col2{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row0_col6{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col6{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col2{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col1{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row1_col6{
#             background-color:  #f3f966;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col4{
#             background-color:  #deee66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row2_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col4{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col2{
#             background-color:  #eff766;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col5{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row3_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col6{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row4_col5{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row5_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col2{
#             background-color:  #eaf466;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row6_col3{
#             background-color:  #d7eb66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col7,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col7{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col4{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row7_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col0{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row8_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col2{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col1{
#             background-color:  #daec66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col3{
#             background-color:  #e2f066;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row9_col5{
#             background-color:  #e5f266;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col0{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row10_col4{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col1{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col3{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row11_col5{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col0,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col1,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col2,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col3,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col4,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col5,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col6,#T_e8e1891e_947a_11eb_b13d_0242ac1c0002row12_col7{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e8e1891e_947a_11eb_b13d_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >day_week</th>        <th class="col_heading level0 col0" >Fri</th>        <th class="col_heading level0 col1" >Mon</th>        <th cl

# %%
colormap = plt.cm.RdBu
pd.crosstab(tvshow['month'],tvshow['day_week'],margins=False).style.background_gradient(cmap=colormap)
# Out:
# <style  type="text/css" >
# #T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col0{
#             background-color:  #65a9cf;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col1{
#             background-color:  #fac8af;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col1,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col0,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col6,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col5,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col3{
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col3,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col2{
#             background-color:  #f6af8e;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col3,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col4{
#             background-color:  #d6604d;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col5{
#             background-color:  #f8bda1;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row0_col6,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col1,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col0,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col3,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col5{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col0{
#             background-color:  #e37e64;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col1{
#             background-color:  #be3036;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col5,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col1{
#             background-color:  #fdddcb;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col3,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col3,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col4{
#             background-color:  #c6413e;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col4{
#             background-color:  #a21328;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col5{
#             background-color:  #960f27;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row1_col6{
#             background-color:  #f6f7f7;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col0{
#             background-color:  #8ac0db;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col1,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col2{
#             background-color:  #cf5246;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col3{
#             background-color:  #f9c6ac;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row2_col6{
#             background-color:  #124984;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col1{
#             background-color:  #bbdaea;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col2{
#             background-color:  #d4e6f1;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col3,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col0{
#             background-color:  #fbe6da;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col5{
#             background-color:  #e58368;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row3_col6{
#             background-color:  #4393c3;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col0,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col0{
#             background-color:  #f8bb9e;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col1,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col1,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col3{
#             background-color:  #9dcbe1;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row4_col5{
#             background-color:  #ef9979;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col0{
#             background-color:  #f19e7d;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col1{
#             background-color:  #e6eff4;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col2,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col1,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col2{
#             background-color:  #2c75b4;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col3{
#             background-color:  #840924;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row5_col6{
#             background-color:  #c43b3c;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col0{
#             background-color:  #f9ede5;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col5{
#             background-color:  #ae172a;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row6_col6,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col6{
#             background-color:  #327cb7;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col6{
#             background-color:  #d1e5f0;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col5{
#             background-color:  #c0dceb;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row7_col6{
#             background-color:  #f3a481;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col1{
#             background-color:  #ab162a;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col2{
#             background-color:  #eb9172;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col3{
#             background-color:  #1b5a9c;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col4{
#             background-color:  #f8f1ed;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row8_col5{
#             background-color:  #deebf2;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col0{
#             background-color:  #fcd5bf;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col4,#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col3{
#             background-color:  #81bad8;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col5{
#             background-color:  #98c8e0;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row9_col6{
#             background-color:  #fae9df;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col5{
#             background-color:  #68abd0;
#             color:  #000000;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row10_col6{
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }#T_e8ea7876_947a_11eb_b13d_0242ac1c0002row11_col0{
#             background-color:  #f8f3f0;

# %% [markdown]
# #### 장르별 분석

# %% [markdown]
# ###### 전세계 장르별로 등록된 컨텐츠 분석

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['#f1eff5', '#b9b0cf', '#171320'])

def genre_heatmap(df, title):
    df['genre'] = df['listed_in'].apply(lambda x :  x.replace(', ',',').split(',')) # listed_in 여러개 항목이 들어있는 부분들을 분리시킴
    Types = []
    for i in df['genre']: Types += i
    Types = set(Types)
    test = df['genre']
    mlb = MultiLabelBinarizer()
    res = pd.DataFrame(mlb.fit_transform(test), columns=mlb.classes_, index=test.index)
    corr = res.corr()
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize=(10, 7))
    if 'Movie' in title:
      fig.text(0,.660, '''
            Genre Correlation: Movie
            ''',fontfamily='serif',fontweight='bold',fontsize=16,ha='right')
    else :
        fig.text(0,.660, '''
            Genre Correlation: TV Show
            ''',fontfamily='serif',fontweight='bold',fontsize=16,ha='right')
    pl = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.4, vmin=-.4, center=0, square=True, linewidths=2.5)
    plt.show()


genre_heatmap(movie, 'Movie')
plt.show()

genre_heatmap(tvshow, 'TV Show')
plt.show()

# %% [markdown]
# ###### 장르별 상위 30개 항목 연도별로 한눈에 보기

# %%
list_in_entire = df10[['listed_in','year']].value_counts().head(30)
df_list=pd.DataFrame(list_in_entire) # 데이터 프레임 변환
df_list =df_list.reset_index() # 인덱스 새로 설정
df_list.columns = ['listed_in',"year",'counts'] 
df_list["year"] = df_list["year"].astype(int) # 연도 int로 변환
sns.relplot(x="year", y="counts", hue="listed_in", size="counts",
             sizes=(30, 400),
               height=6, data=df_list)

# %% [markdown]
# ###### 장르별 상위 10개 시각화 - 전체 데이터

# %%
list_in_entire=df10['listed_in'].value_counts().head(10) # listed_in 상위 10개 항목 추출
list_in_entire.plot.barh(color= 'orange') # 가로 막대그래프로 시각화_in 상위 10개 항목 추출
plt.title("Neflix contents genre")
plt.show()

# %% [markdown]
# ## 코로나전(2019년)과 코로나 후(2020년)의 컨텐츠 비교

# %% [markdown]
# #### 2019년과 2020년의 연령별 데이터 비교

# %% [markdown]
# - 코로나 전과 후의 rating별 컨텐츠 비교

# %%
plt.figure(figsize=(10,14))
# 2019년 rating 비율 ( pie plot )
df_rating_2019 = df['rating_age_cat'][df['year']==2019].value_counts()

plt.subplot(1,2,1)
plt.title('<rating ratio of 2019>')
df_rating_2019.plot(kind = 'pie', explode=[0.02,0.02, 0.03, 0.03], autopct='%1.1f%%', colors=['#fdaabb', '#a7d8fd', '#ffef8e', '#9bffa2'])

# 2020년 rating 비율 ( pie plot )
df_rating_2019 = df['rating_age_cat'][df['year']==2020].value_counts()

plt.subplot(1,2,2)
plt.title('<rating ratio of 2020>')
df_rating_2019.plot(kind = 'pie', explode=[0.02,0.02, 0.03, 0.03], autopct='%1.1f%%', colors=['#fdaabb', '#a7d8fd', '#ffef8e', '#9bffa2'])

plt.tight_layout()  # 그래프 사이 간격 자동 조정
plt.show()

# %% [markdown]
#
#
# #####연령 데이터 비교 (선, 막대)

# %%
# 2019년 rating 비율  --> 선 그래프
df_rating_2019 = df['rating_age_cat'][df['year']==2019].value_counts()
df_rating_2019

x2019 = df_rating_2019.index
y2019 = df_rating_2019.values

plt.subplot(2,1,1)
plt.xlabel('rating')
plt.ylabel('number')
plt.title('<rating_age of 2019>')
sns.pointplot(x=x2019, y=y2019, linestyles  = '-', color='#ff8888') # 분홍색

# 2019년 rating 비율
df_rating_2020 = df['rating_age_cat'][df['year']==2020].value_counts()
df_rating_2020

x2020 = df_rating_2020.index
y2020 = df_rating_2020.values

plt.subplot(2,1,2)
plt.xlabel('rating')
plt.ylabel('number')
plt.title('<rating_age of 2020>')
sns.pointplot(x=x2020, y=y2020, linestyles  = '-', color='#b0e1ff') # 하늘색

plt.tight_layout()  # 그래프 사이 간격 자동 조정
plt.figure(figsize=(40,10))
plt.show()

df_test = df[(df['year'] == 2019) | (df['year'] == 2020)]
plt.figure(figsize=(8,6))
plt.title('<rating_age comparison of 2019 & 2020>')
sns.countplot('rating_age_cat', hue='year',data=df_test, palette = ['#ff8888','#b0e1ff'])

# %% [markdown]
# #### 코로나 대유행시(2020년) 전세계 넷플릭스 월별 새로 등록된 컨텐츠 수
#
# - 1월에 비해 전세계적으로 코로나의 대확산이 심각해진 2월에 컨텐츠 등록 수가 급감한 것으로 보인다.

# %%
df['month_added']=df['date_added'][df['year']==2020].dt.month_name() # 월 이름을 열로 추가
df['year_added'] = df['date_added'][df['year']==2020].dt.year # 년도를 추가
monthdf = df.groupby('type')['month_added'].value_counts().unstack().fillna(0).loc[['TV Show','Movie']].cumsum(axis=0).T # 타입별 월별로 데이터 재구조화후 결측치 0으로 채운후 전치행렬
monthdf2 = monthdf
monthdf2['Value'] = monthdf2['Movie'] + monthdf2['TV Show'] # 두개의 항목을 더해서 전체 합을 구하기
monthdf2.reset_index(inplace=True) # 인덱스 재설정

df_m = monthdf2.sort_values(by='Value',ascending=False) # 총합이 큰 순으로 정렬
color_map = ['#b9b0cf' for _ in range(12)]
color_map[0] = color_map[11] =  '#b20710'

#초기화
plt.figure(figsize=(8,8))
ax = plt.subplot(111, polar=True)
plt.axis('off')

#레이아웃조정
upperLimit = 30
lowerLimit = 1
labelPadding = 30
#최댓값
max = df_m['Value'].max()

#높이 계산
#데이터셋안의 0은 Lowerlimit(10) max는 upperlimit(100)
slope = (max - lowerLimit) / max
heights = slope * df_m.Value + lowerLimit
#너비계산 2*pi=360도
width = 2*np.pi / len(df_m.index)
#각도계산
indexes = list(range(1, len(df_m.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color=color_map,alpha=0.8
)

for bar, angle, height, label in zip(bars,angles, heights, df_m["month_added"]):
    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    #레이블달기
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, fontsize=20,fontfamily='serif',
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %% [markdown]
# #### 코로나 전인 2019년 장르별 상위 10개 확인하기

# %%
df10['year']=df10['year'].astype(int) # object형을 int형으로 변환
list_2019 = df10[["listed_in",'year']][df10["year"]==2019] # 2019년 리스트 불러오기
top10_2019 = list_2019.value_counts().sort_values(ascending=False).head(10) # 2019년 리스트 상위 10개항목만 정렬
top10_2019.plot.barh(color= 'orange')
plt.title("Neflix contents genre_2019")
plt.show()

# %% [markdown]
# #### 코로나 후인 2020년 장르 상위 10개 확인하기

# %%
# 2020년 장르 상위 10개 bar 시각화
list_2020 = df10[["listed_in",'year']][df10["year"]==2020]  # 2020년 리스트 불러오기
top10_2020 = list_2020.value_counts().sort_values(ascending=False).head(10) # 2020년 리스트 상위 10개항목만 정렬
top10_2020.plot.barh(color= 'orange')
plt.title("Neflix contents genre_2020")

plt.show()

# %% [markdown]
# ## 한국의 데이터 분석

# %% [markdown]
# #### 한국의 유형별 컨텐츠 수 비교

# %%
df_Korea = df[df['country'] == 'South Korea']
df_notKorea = df[df['country'] != 'South Korea']

# %% [markdown]
# 가설) 한국에서는 TV Show 콘텐츠 생산이 영화 생산보다 많을 것이다.

# %%
plt.figure(figsize=(10, 14))

df_Korea = df[df['country'] == 'South Korea']
df_Korea_type = df_Korea['type'].value_counts()

df_notKorea = df[df['country'] != 'South Korea']
df_notKorea_type = df_notKorea['type'].value_counts()

plt.subplot(1,2,1)
plt.title('<type comparison of Korea>')
df_Korea_type.plot(kind = 'pie', explode=[0.01,0.05], autopct='%1.1f%%', colors=['#F9C1BD', '#DDDDDD'])

plt.subplot(1,2,2)
plt.title('<type comparison of non Korea>')
df_notKorea_type.plot(kind = 'pie', explode=[0.01,0.05], autopct='%1.1f%%',colors=['#F4DB9E', '#DDDDDD'])

plt.tight_layout()  # 그래프 사이 간격 자동 조정
plt.show()

# %% [markdown]
# #### 한국의 등록년도별 컨텐츠 수 비교
#
# *  2019년에 왜 많았는지 추측해보기
#    -> 킹덤의 대유행 등

# %%
df_Korea_year = df_Korea['year'].astype('int').value_counts().sort_index()

x_korea = df_Korea_year.index[0:5]
y_korea = df_Korea_year.values[0:5]
korea_index = np.arange(len(x_korea))

plt.xlabel('added_year')
plt.ylabel('contents')
plt.title('<added_year comparison of Korea>')
plt.plot(y_korea, color = '#B492FF', marker = 'o')
plt.xticks(korea_index, x_korea)
plt.show()

# %% [markdown]
# #### 한국을 제외한 나라의 등록년도 비교

# %%
df_notKorea_year = df_notKorea['year'].astype('int').value_counts().sort_index()

x_notkorea = df_notKorea_year.index[8:13]
y_notkorea = df_notKorea_year.values[8:13]
notkorea_index = np.arange(len(x_notkorea))


plt.xlabel('added_year')
plt.ylabel('contents')
plt.title('<added_year comparison of non Korea>')
plt.plot(y_notkorea, color = '#ffe666', marker = 'o')
plt.xticks(notkorea_index, x_notkorea)
plt.show()

# %% [markdown]
# #### 한국의 컨텐츠 출시 날짜

# %%
df_Korea_relaese = df_Korea['release_year'].value_counts()
plt.xlabel('release year')
plt.ylabel('contents')
plt.title('<release_year comparison of Korea>')
df_Korea_relaese.plot(kind = 'barh', color = '#ffd571')

# %% [markdown]
# #### rating 으로 분류

# %%
df_Korea_rating = df_Korea['rating'].value_counts()
df_Korea_rating
plt.xlabel('rating')
plt.ylabel('contents')
plt.title('<rating comparison of Korea>')
df_Korea_rating.plot(kind = 'bar', color = '#F9C1BD')

# %%
# 한국제외
df_notKorea_rating = df_notKorea['rating'].value_counts()

plt.xlabel('rating')
plt.ylabel('contents')
plt.title('<rating comparison of non Korea>')
df_notKorea_rating.plot(kind = 'bar', color = '#F4DB9E')

# %% [markdown]
# #### 한국의 listed in 비교

# %%
from sklearn.preprocessing import MultiLabelBinarizer
import matplotlib.colors

cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['#A30DCC','#E7C2F0','#B033D2'])

def genre_heatmap(df, title):
  
    df_Korea['splite_listed_in'] = df_Korea['listed_in'].str.replace(', ', ',').str.split(',')

    listed_in_all = []
    for x in df_Korea['splite_listed_in']:
      listed_in_all += x

    listed_in_all = set(listed_in_all)

    test = df_Korea['splite_listed_in']
    mlb = MultiLabelBinarizer()
    res = pd.DataFrame(mlb.fit_transform(test), columns=mlb.classes_, index=test.index)
    corr = res.corr()
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize=(10, 7))
    fig.text(.54,.88,'Genre correlation', fontfamily='serif',fontweight='bold',fontsize=16)

    pl = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.5, vmin=-.5, center=0, square=True, linewidths=2.5)
    plt.show()

df_Korea = df[df['country'] == 'South Korea']

genre_heatmap(df_Korea, 'Korea')
plt.show()

# %% [markdown]
# ## 넷플릭스 등록 데이터 지도로 분석

# %% [markdown]
# - 세계지도 데이터셋 불러오기

# %%
df_location = pd.read_csv(drive_path + 'world_location.csv')

# %% [markdown]
# - 상위 100개 나라 확인 후 데이터프레임으로 변환

# %%
world_map = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

#전체 컨테츠 등록 갯수 상위 100개 나라 확인 후 데이터프레임으로 변환  
df_country_count = df['country'].value_counts()
df_country_count = df_country_count.rename_axis('name').to_frame('count') # 인덱스 재정렬

# %% [markdown]
# - 기존 위치 데이터프레임과 위치 데이터 프레임 병합

# %%
df_location = df_location[['name','latitude','longitude']] # 이름, 위도, 경도 가져오기
df_new_location = pd.merge(df_location,df_country_count,how='outer',on='name') # 병합하기

#누락 데이터 제거 
df_new_location = df_new_location.dropna(axis=0)

# %% [markdown]
# - 데이터 프레임 확인하기

# %%
df_new_location.sort_values(by='count',ascending =False) # count를 기준으로 정렬
df_new_location['count'] = df_new_location['count'].astype(int) # count를 int형으로 변환
df_new_location['marker_color'] = pd.cut(df_new_location['count'],bins = 3, labels=['orange','green','violet']) # 3개의 영역으로 분할시키기

# %% [markdown]
# - 지도 뽑아내기

# %%
# 위치 마커 표시 , popup창에 나라 이름과 컨텐츠 갯수 표시 

for name, count, lat, lng, marker_color,x in zip(df_new_location['name'].astype(str),df_new_location['count'].astype(str),df_new_location['latitude'],df_new_location['longitude'],df_new_location['marker_color'],df_new_location['count']):
    html = """<body style="background-color:yellow;"><p style="color:red;">"""+name+"""</p><p>count:"""+count+"""</p>"""
    iframe = folium.IFrame(html,width=160,height=80)
    popup = folium.Popup(iframe)
    folium.Circle(radius= x *1000,location=[lat,lng], popup=popup, color=marker_color).add_to(world_map)
      
display(world_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_a674c8f0a1474999b2da9b544f12adfd%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a674c8f0a1474999b2da9b544f12adfd%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_a674c8f0a1474999b2da9b544f12adfd%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_a674c8f0a1474999b2da9b544f12adfd%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B20%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_e66ab1339b9b47a3a266758df122fa47%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22detec ...

# %% [markdown]
# ## 기타 분석

# %% [markdown]
# #### 가장 많이 출연한 배우 알아보기

# %%
cast_counter_list = dict(Counter(df12['cast']).most_common(5))
freq_actor=pd.DataFrame({'actor_name':cast_counter_list.keys(),'Num_Movies':cast_counter_list.values()})

plt.figure(figsize=(10,7))
sns.barplot(x=freq_actor.actor_name,y=freq_actor['Num_Movies'])
plt.xticks(rotation=20)
plt.title('Most Popular Actor', fontsize=20)
plt.show()

# %% [markdown]
# #### tvshow의 Season이 얼마나 지속되는지 확인해보기

# %%
tvshow_season = tvshow_s.groupby('duration')["show_id"].count().reset_index(name='count').sort_values(by='count', ascending=False)
plt.figure(figsize=(16, 6))
sns.barplot(x='duration',y='count',data=tvshow_season)

# %% [markdown]
# #### 컨텐츠 상위 5개국 영화길이가 얼마나 되는지 확인해보기

# %%
df3
# Out:
#       show_id   type  ... country_United Kingdom country_United States
# 3           4  Movie  ...                      0                     1
# 4           5  Movie  ...                      0                     1
# 7           8  Movie  ...                      0                     1
# 8           9  Movie  ...                      0                     0
# 9          10  Movie  ...                      0                     0
# ...       ...    ...  ...                    ...                   ...
# 7776     7777  Movie  ...                      0                     0
# 7778     7779  Movie  ...                      0                     1
# 7780     7781  Movie  ...                      0                     0
# 7781     7782  Movie  ...                      0                     1
# 7783     7784  Movie  ...                      0                     0
#
# [3099 rows x 17 columns]

# %%
movie_top = movie_s['country'].value_counts().head(5).index

df2 = []
# movie_top_list
for i in range(len(movie_s)):
    if movie_s.iloc[i]['country'] in movie_top:
        df2.append(movie_s.iloc[i])
        
df2 = pd.DataFrame(df2)
df3 = pd.get_dummies(df2,columns=['country'])
df4 = df3.iloc[:,10:]

df4.groupby(['time_category']).sum().sort_values(by='time_category',ascending=True).plot.bar(alpha=0.5, rot=45, width=1 ,edgecolor='black')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')
